# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm
import pickle

# %%
filenames= []
for file in os.listdir('TEST'):
    filenames.append(os.path.join('TEST',file))

# %%
filenames[0:5]
# Out:
# ['TEST\\1000851.yaml',
#  'TEST\\1000853.yaml',
#  'TEST\\1000855.yaml',
#  'TEST\\1000881.yaml',
#  'TEST\\1000883.yaml']

# %%
final_df=pd.DataFrame()
counter=1
for file in tqdm(filenames):
    with open(file,'r')as f:
        df=pd.json_normalize(safe_load(f))
        df['match_id']=counter
        final_df=final_df.append(df)
        counter+=1
final_df
# Out:
#   0%|                                                                                          | 0/629 [00:00<?, ?it/s]C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\2750570498.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(df)
#   0%|▏                                                                                 | 1/629 [00:02<30:17,  2.89s/it]C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\2750570498.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df=final_df.append(df)
# ...

# %%
backup=final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'dec...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Pakistan', 'declare...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#    meta.created  meta.revision     info.city  \
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.dates',
    'info.outcome.by.wickets',
  
   
    'info.outcome.result',
     
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets',
    
],inplace=True)

# %%
final_df
# Out:
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'South Africa', 'del...         Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        Hobart
# 0   [{'1st innings': {'team': 'South Africa', 'dec...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...      Brisbane
# 0   [{'1st innings': {'team': 'Pakistan', 'declare...           NaN
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Johannesburg
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Colombo
#
#    info.gender info.match_type info.outcome.winner info.player_of_match  \
# 0         male            Test        South Africa           [K Rabada]
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# male      624
# female      4
# Name: info.gender, dtype: int64

# %%
final_df=final_df[final_df['info.gender']=='male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\2343689724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'South Africa', 'del...         Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        Hobart
# 0   [{'1st innings': {'team': 'South Africa', 'dec...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...      Brisbane
# 0   [{'1st innings': {'team': 'Pakistan', 'declare...           NaN
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Johannesburg
# ...

# %%
final_df.drop(columns=['info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\2755951393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.match_type'],inplace=True)
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'South Africa', 'del...         Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        Hobart
# 0   [{'1st innings': {'team': 'South Africa', 'dec...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...      Brisbane
# 0   [{'1st innings': {'team': 'Pakistan', 'declare...           NaN
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Johannesburg
# ...

# %%
pickle.dump(final_df,open('dataset_level3_TEST.pkl','wb'))
matches=pickle.load(open('dataset_level3_TEST.pkl','rb'))
matches
# Out:
#                                               innings     info.city  \
# 0   [{'1st innings': {'team': 'South Africa', 'del...         Perth
# 0   [{'1st innings': {'team': 'Australia', 'delive...        Hobart
# 0   [{'1st innings': {'team': 'South Africa', 'dec...           NaN
# 0   [{'1st innings': {'team': 'Australia', 'delive...      Brisbane
# 0   [{'1st innings': {'team': 'Pakistan', 'declare...           NaN
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'South Africa', 'del...     Cape Town
# 0   [{'1st innings': {'team': 'South Africa', 'del...  Johannesburg
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...           NaN
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...       Colombo
#
#    info.outcome.winner info.player_of_match                 info.teams  \
# 0         South Africa           [K Rabada]  [Australia, South Africa]
# ...

# %%
count=1
delivery_df=pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,263,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match=[]
    batsman=[]
    bowler=[]
    runs=[]
    player_of_dismissed=[]
    teams=[]
    batting_team=[]
    match_id=[]
    city=[]
    venue=[]
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df=pd.DataFrame({
        'match_id':match_id,
        'teams':teams,
        'batting_team':batting_team,
        'ball':ball_of_match,
        'batsman':batsman,
        'bowler':bowler,
        'runs':runs,
        'player_dismissed':player_of_dismissed,
        'city':city,
        'venue':venue
      })
    delivery_df=delivery_df.append(loop_df)
# Out:
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\4254820535.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df=delivery_df.append(loop_df)
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\4254820535.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df=delivery_df.append(loop_df)
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\4254820535.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df=delivery_df.append(loop_df)
# C:\Users\debaj\AppData\Local\Temp\ipykernel_4408\4254820535.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df=delivery_df.append(loop_df)
# ...

# %%
delivery_df
# Out:
#      match_id                      teams  batting_team   ball         batsman  \
# 0           2  [Australia, South Africa]  South Africa    0.1         SC Cook
# 1           2  [Australia, South Africa]  South Africa    0.2         SC Cook
# 2           2  [Australia, South Africa]  South Africa    0.3         SC Cook
# 3           2  [Australia, South Africa]  South Africa    0.4         SC Cook
# 4           2  [Australia, South Africa]  South Africa    0.5         HM Amla
# ..        ...                        ...           ...    ...             ...
# 843       625     [Sri Lanka, Australia]     Sri Lanka  140.3  PADLR Sandakan
# 844       625     [Sri Lanka, Australia]     Sri Lanka  140.4  PADLR Sandakan
# 845       625     [Sri Lanka, Australia]     Sri Lanka  140.5  PADLR Sandakan
# 846       625     [Sri Lanka, Australia]     Sri Lanka  140.6  PADLR Sandakan
# 847       625     [Sri Lanka, Australia]     Sri Lanka  141.1      RAS Lakmal
#
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team']= delivery_df.apply(bowl,axis=1)
delivery_df
# Out:
#      match_id                      teams  batting_team   ball         batsman  \
# 0           2  [Australia, South Africa]  South Africa    0.1         SC Cook
# 1           2  [Australia, South Africa]  South Africa    0.2         SC Cook
# 2           2  [Australia, South Africa]  South Africa    0.3         SC Cook
# 3           2  [Australia, South Africa]  South Africa    0.4         SC Cook
# 4           2  [Australia, South Africa]  South Africa    0.5         HM Amla
# ..        ...                        ...           ...    ...             ...
# 843       625     [Sri Lanka, Australia]     Sri Lanka  140.3  PADLR Sandakan
# 844       625     [Sri Lanka, Australia]     Sri Lanka  140.4  PADLR Sandakan
# 845       625     [Sri Lanka, Australia]     Sri Lanka  140.5  PADLR Sandakan
# 846       625     [Sri Lanka, Australia]     Sri Lanka  140.6  PADLR Sandakan
# 847       625     [Sri Lanka, Australia]     Sri Lanka  141.1      RAS Lakmal
#
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['South Africa', 'Australia', 'Pakistan', 'Bangladesh',
#        'New Zealand', 'India', 'West Indies', 'Zimbabwe', 'England',
#        'Sri Lanka', 'Ireland', 'Afghanistan'], dtype=object)

# %%
teams=['Australia','India','Bangladesh','New Zealand','South Africa','England'
       'West Indies','Afganistan','Pakistan','Sri Lanka','Zimbabwe','Ireland',
       
       ]

# %%
delivery_df=delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df=delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
output=delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id  batting_team bowling_team   ball  runs player_dismissed  \
# 0           2  South Africa    Australia    0.1     0                0
# 1           2  South Africa    Australia    0.2     0                0
# 2           2  South Africa    Australia    0.3     0                0
# 3           2  South Africa    Australia    0.4     0          SC Cook
# 4           2  South Africa    Australia    0.5     0                0
# ..        ...           ...          ...    ...   ...              ...
# 843       625     Sri Lanka    Australia  140.3     0                0
# 844       625     Sri Lanka    Australia  140.4     0                0
# 845       625     Sri Lanka    Australia  140.5     0                0
# 846       625     Sri Lanka    Australia  140.6     4                0
# 847       625     Sri Lanka    Australia  141.1     0       RAS Lakmal
#
#         city                                         venue
# ...

# %%
pickle.dump(output,open('dataset_level3_TEST.pkl','wb'))
